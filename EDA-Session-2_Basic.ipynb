# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\rosha\OneDrive\Documents\Data Science\Batch-Jan23\5.Data-Files\Visadataset.csv")
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $head$
#
# **Top 5 rows**

# %%
# dataframe_name.head
# by default 5 rows. we can specify as an argument if we require specific number of rows
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# $tail$
#
# **Last rows from datafram**

# %%
df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
df.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %% [markdown]
# $shape$
#
# **Number of rows and number of columns**

# %%
df.shape
# Out:
# (25480, 12)

# %%
print(f"The number of rows : {df.shape[0]} and number of columns : {df.shape[1]})")
# Out:
# The number of rows : 25480 and number of columns : 12)

# %% [markdown]
# $size$
#
# **how  many indices provided by size**

# %%
df.size # 25480*12
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $dtypes$
#
# **data types**

# %%
df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
# object - categorical
# other than object is numerical - int64, float64

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
# Task 1 - Extract numerical columns and categorical columns seperately by using dtypes

# %%
d1=dict(df.dtypes)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# Categorical data available
df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.select_dtypes(exclude='object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# $isnull$
#
# **check if data has any missing values or null values**

# %%
df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
# gives number of missing values column-wise
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $info$

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$-$loc$-$iloc$

# %%
df.take([4,5,6])
# 2,3,4 or columns or rows?
# axis=1 gives you column
# axix=0 gives you rows
# dafualt is 0 that is why return rows
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
# 6  EZYV07      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 4        149907.39         Year                  Y   Certified
# 5         78252.14         Year                  Y   Certified
# 6         53635.39         Year                  Y   Certified

# %%
df.take([0,2,5], axis=1)
# Out:
#          case_id education_of_employee  no_of_employees
# 0         EZYV01           High School            14513
# 1         EZYV02              Master's             2412
# 2         EZYV03            Bachelor's            44444
# 3         EZYV04            Bachelor's               98
# 4         EZYV05              Master's             1082
# ...          ...                   ...              ...
# 25475  EZYV25476            Bachelor's             2601
# 25476  EZYV25477           High School             3274
# 25477  EZYV25478              Master's             1121
# 25478  EZYV25479              Master's             1918
# 25479  EZYV25480            Bachelor's             3195
#
# [25480 rows x 3 columns]

# %%
df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
df.take([100,200,300]).take([4,8,11], axis=1)
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %% [markdown]
# $iloc$

# %%
# df.iloc[<rows>,<columns>]
# df.iloc[<start:end>,<start:end>]
# rows=[]
# columns=[]
# df.iloc[rows, columns]

# %%
df.iloc[5:10,:]
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
# 7                     N             3035         1924                 West
# 8                     N             4810         2012              Midwest
# 9                     N             2251         1995                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
df.iloc[5:10,2:4]
# Out:
#   education_of_employee has_job_experience
# 5              Master's                  Y
# 6            Bachelor's                  N
# 7            Bachelor's                  Y
# 8            Bachelor's                  N
# 9             Doctorate                  Y

# %%
df.iloc[:,5:10]
# Out:
#        no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0                14513         2007                 West         592.2029
# 1                 2412         2002            Northeast       83425.6500
# 2                44444         2008                 West      122996.8600
# 3                   98         1897                 West       83434.0300
# 4                 1082         2005                South      149907.3900
# ...                ...          ...                  ...              ...
# 25475             2601         2008                South       77092.5700
# 25476             3274         2006            Northeast      279174.7900
# 25477             1121         1910                South      146298.8500
# 25478             1918         1887                 West       86154.7700
# 25479             3195         1960              Midwest       70876.9100
#
#       unit_of_wage
# 0             Hour
# 1             Year
# ...

# %%
df.iloc[[100,200,300,400,500],[4,8,11]]
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified
# 400                     N        113927.99   Certified
# 500                     N         92549.52   Certified

# %%
df.iloc[[100,200,300,400,500],[8]]
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21
# 400        113927.99
# 500         92549.52

# %%
df.loc[[100,200,300,400,500],['prevailing_wage']]
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21
# 400        113927.99
# 500         92549.52

# %%
# df.iloc[5:10,:]
# df.iloc[5:10,2:4]
# df.iloc[:,5:10]
# df.iloc[[100,200,300,400,500],[4,8,11]]
# both below gives same output
# df.iloc[[100,200,300,400,500],[8]] # need to count the index and provide the number
# df.loc[[100,200,300,400,500],['prevailing_wage']] # no need to count indexex

# %%
# pandas.core.frame.DataFrame
# pandas.core.indexes.base.Index
# pandas.core.series.Series
